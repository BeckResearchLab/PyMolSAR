# %% [markdown]
# ### Imports

# %%
import pandas as pd
from smdt import datasets
from smdt import molecular_descriptors

# %% [markdown]
# ### Data

# %%
data = datasets.usp_inhibition()

# %% [markdown]
# ### Descriptors

# %%
# %%time
descriptor_data = molecular_descriptors.getAllDescriptors(data,nprocs=20)
descriptor_data.to_csv('USP-Inhibition.csv')

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# ### Models

# %% [markdown]
# ### Comparison of All Models
