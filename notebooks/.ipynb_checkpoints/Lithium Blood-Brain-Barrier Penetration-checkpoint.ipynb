# %% [markdown]
# # Lithium Blood-Brain-Barrier Penetration Classification

# %% [markdown]
# ### Imports

# %%
from smdt import datasets, molecular_descriptors, classification, metrics
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Data

# %% [markdown]
# #### Data Loading

# %%
LiBloodBarrier = datasets.load_LiBloodBarrier()
# Out:
# Reference:
# Hu Li, Chun Wei Yap, Choong Yong Ung, Ying Xue, Zhi Wei Cao and Yu Zong Chen, J. Chem. Inf. Model. 2005

# %% [markdown]
# #### Descriptor Calculation

# %%
data = molecular_descriptors.getAllDescriptors(LiBloodBarrier)
# Out:
# Calculating Molecular Descriptors...
# Row 387 out of 387
# Calculating Molecular Descriptors Completed.

# %% [markdown]
# #### Data Cleaning

# %%
y = data['Target']
X = data.drop(['Target'], axis=1)

# %% [markdown]
# #### Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# %% [markdown]
# ### Models

# %% [markdown]
# #### Gaussian Naive Bayes

# %%
scores1, feature_names1, y_score1 = classification.fit_GaussianNB(X_train, X_test, y_train, y_test, 'n')
# Out:
# Training data best accuracy: 0.71793
# Testing data accuracy: 0.72745
#
# Classification Report:
#              precision    recall  f1-score   support
#
#           n       0.56      0.69      0.62        32
#           p       0.83      0.74      0.78        65
#
# avg / total       0.74      0.72      0.73        97

# %% [markdown]
# #### K Nearest Neighbors

# %%
scores2, feature_names2, y_score2 = classification.fit_KNearestNeighbors(X_train, X_test, y_train, y_test, 'n')
# Out:
# Training data best accuracy: 0.87762
# Testing data accuracy: 0.77627
#
# Classification Report:
#              precision    recall  f1-score   support
#
#           n       0.64      0.72      0.68        32
#           p       0.85      0.80      0.83        65
#
# avg / total       0.78      0.77      0.78        97

# %% [markdown]
# #### Linear SVC

# %%
scores3, feature_names3, y_score3 = classification.fit_LinearSVC(X_train, X_test, y_train, y_test, 'n')
# Out:
# Training data best accuracy: 0.78791
# Testing data accuracy: 0.75439
#
# Classification Report:
#              precision    recall  f1-score   support
#
#         0.0       0.83      0.80      0.81        65
#         1.0       0.62      0.66      0.64        32
#
# avg / total       0.76      0.75      0.75        97

# %% [markdown]
# #### Random Forest Classifier

# %%
scores4, feature_names4, y_score4 = classification.fit_RandomForestClassifier(X_train, X_test, y_train, y_test, 'n')
# Out:
# Training data best accuracy: 0.89617
# Testing data accuracy: 0.80152
#
# Classification Report:
#              precision    recall  f1-score   support
#
#           n       0.72      0.66      0.69        32
#           p       0.84      0.88      0.86        65
#
# avg / total       0.80      0.80      0.80        97

# %% [markdown]
# #### SGD Classifier

# %%
scores5, feature_names5, y_score5 = classification.fit_SGDClassifier(X_train, X_test, y_train, y_test, 'n')
# Out:
# Training data best accuracy: 0.77070
# Testing data accuracy: 0.78580
#
# Classification Report:
#              precision    recall  f1-score   support
#
#         0.0       0.85      0.82      0.83        65
#         1.0       0.66      0.72      0.69        32
#
# avg / total       0.79      0.78      0.79        97

# %% [markdown]
# #### MLP Classifier

# %%
scores6, feature_names6, y_score6 = classification.fit_MLPClassifier(X_train, X_test, y_train, y_test, 'n')

# %% [markdown]
# ### Final Plots
